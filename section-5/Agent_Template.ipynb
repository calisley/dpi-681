# %% [markdown]
# <a href="https://colab.research.google.com/github/calisley/dpi-681/blob/main/section-5/Agent_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Run this before running your agent! Otherwise it will not work.

# %%
# @title
# !pip install openai-agents pydantic gymnasium openai openai-guardrails

# %%
# @title
from google.colab import userdata
import os
import requests
import nest_asyncio
import openai
nest_asyncio.apply()
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
from agents import set_tracing_export_api_key
set_tracing_export_api_key(os.getenv("OPENAI_API_KEY"))

# %%
# !pip uninstall -y guardrails-ai

# %% [markdown]
# # Pre-coded functions for use
#
# These are the functions we used last time. We will need to reimplement them in our model code. In general, whenever we use custom tools, remember that we have to write them ourselves.

# %%
def get_weather_by_coordinates(latitude: int, longitude: int):
  response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m,wind_speed_10m&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m")
  data = response.json()
  return data['current']['temperature_2m']

def square_number(number: int):
  return number ** 2

# %% [markdown]
# # Template for deploying your Agent

# %%
# PUT YOUR GENERATED CODE HERE

# %% [markdown]
# After you have imported your agent code, run this block!

# %%
workflow_input = WorkflowInput(input_as_text=input("What is your question: "))
result = await run_workflow(workflow_input)
print(result)
